# %% [markdown]
# <a href="https://colab.research.google.com/github/Luicazen/NLPTweets/blob/NN/readme1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NLP Tweets: Project Milestone
# ###
# This competition measures success by the highest f1-score. To determine how effective a base level model would be without any tuning i ran the
# 4 models listed below.
# These initial models had variable measures of success:
# 1. Linear Regression -> f1-score: 0.5938
# 2. Random Forrest -> f1-score: 0.3706
# 3. Support Vector Machine -> f1-score: 0.7148 </br>
# 4. Neural Network -> f1-score: 0.7441
# Since The Neural Network scored the highest initially, i will begin tuning it.
