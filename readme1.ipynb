# %% [markdown]
# <a href="https://colab.research.google.com/github/Luicazen/NLPTweets/blob/main/README1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NLP Tweets: Project Milestone
# ###
# This competition measures success by the highest f1-score. To determine how effective a base level model would be without any tuning i ran
# 3 models. I plan on adding a neural network as a 4th initial model. Based on the initial scoring, my hypothesis that a SVM would do best with natural language processing seems to still be the case.
# These initial models had variable measures of success:
# 1. Linear Regression -> f1-score: 0.5938
# 2. Random Forrest -> f1-score: 0.3706
# 3. Support Vector Machine -> f1-score: 0.7148 </br>
